# %%
import tweepy as tw
import pandas as pd
import nltk
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-28931a9b9410> in <module>
#       1 import tweepy as tw
#       2 import pandas as pd
# ----> 3 import nltk
#
# ~\anaconda3\lib\site-packages\nltk\__init__.py in <module>
#     126 # Import top-level functionality into top-level namespace
#     127
# --> 128 from nltk.collocations import *
#     129 from nltk.decorators import decorator, memoize
#     130 from nltk.featstruct import *
#
# ~\anaconda3\lib\site-packages\nltk\collocations.py in <module>
#      37
#      38 # these two unused imports are referenced in collocations.doctest
# ---> 39 from nltk.metrics import (
#      40     ContingencyMeasures,
#      41     BigramAssocMeasures,
#
# ~\anaconda3\lib\site-packages\nltk\metrics\__init__.py in <module>
#      14 """
#      15
# ---> 16 from nltk.metrics.scores import (
#      17     accuracy,
# ...

# %%
consumer_key= 'OPxpPG4pWKfk9dMSHWRHgqeTM'
consumer_secret= 'WR4u8BCObFU0pIiVVIsHIVRZxx5pbnaW8S8pp3IGGlP2vgr7U6'
access_token= '1358021042812329985-GAzvHOjbwxvmIa3HF1mHnk1aDTw9aS'
access_token_secret= 'tbRuOQDFsILwnDaRRwICQkkqqKodK9yMLl3nsFbRFrW7M'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
search_words = "#Avalanche"
date_since = "2021-2-1"

# %%
tweets = tw.Cursor(api.search,
                       q=search_words,
                       lang="en",
                       since=date_since).items(100)


# Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
'[tweet.text for tweet in tweets]'
# Out:
# RT @WeatherBug: A deadly #avalanche hit Utah's backcountry ski area this weekend. Latest...https://t.co/x81lubAkot https://t.co/ezOf1lQfbh
# RT @C_MAlexander: You know the weather is bad when an #avalanche warning has been issued for hills in #Fife! This from @FCCTrust: “be aware…
# @AvalancheHub @avalancheavax @real_morpheus @aCryptoBiker @Andyvargtz @Andrea07_lc @avax_coin @Ahnor_Block @rminchv… https://t.co/TuZVmiV6O7
# The blockchain space is full of wild assets, networks, dapps, entities and projects
#
# The non-digitized asset world… https://t.co/Y5xiKLyyRc
# RT @C_MAlexander: You know the weather is bad when an #avalanche warning has been issued for hills in #Fife! This from @FCCTrust: “be aware…
# RT @AvalancheHub: We made it! From an idea to our great @avalancheavax community.
# Many of you have been participating in the #Avalanche com…
# RT @WSOnlineNews: BC man able to dig out elk buried in avalanche
# https://t.co/0Wpf3BRSHs #Avalanche #bcpoli #elk
# ...

# %%
new_search="covid+2021 -filter:retweets"
tweets = tw.Cursor(api.search, 
                           q=new_search,
                           lang="en",
                           since=date_since).items(5)

users_locs = [[tweet.user.screen_name, tweet.user.location] for tweet in tweets]
users_locs
# Out:
# [['DCManitobaInc', 'Winnipeg, Manitoba'],
#  ['Monarchglobalh', ''],
#  ['4_the_babies', 'California, USA'],
#  ['Monarchglobalh', ''],
#  ['HomeFirstChoice', 'Ohio']]

# %%
tweet_text = pd.DataFrame(data=users_locs, 
                    columns=['user', "location"])
tweet_text
# Out:
#               user            location
# 0    DCManitobaInc  Winnipeg, Manitoba
# 1   Monarchglobalh
# 2     4_the_babies     California, USA
# 3   Monarchglobalh
# 4  HomeFirstChoice                Ohio

# %%
user = api.get_user('@JoeBieden')
print(user.screen_name)
print(user.followers_count)
print(user.status.text)
for friend in user.friends():
   print(friend.screen_name)
# Out:
# JoeBieden
# 6
# I'm in the running to win an Intel i7 8700K Processor in @JackFrags Competition! https://t.co/0pKvzxFbCx
# IntelUK
# jackfrags
# SnoopDogg
# Tip
# BigSean
# RepPerlmutter
# mindykaling
# chelseahandler
# RepDianaDeGette
# common
# BernieSanders
# neiltyson
# ciara
# SenSanders
# SenWarren
# johnlegend
# kendricklamar
# MeekMill
# kumailn
# daisymarquez_

# %%
tweetCount = 20
user="nytimes"
# Calling the user_timeline function with our parameters
results = api.user_timeline(id=user, count=tweetCount)

# foreach through all tweets pulled
for tweet in results:
   # printing the text stored inside the tweet object
   print(tweet.text)
# Out:
# RT @nytgraphics: We continue to monitor virus restrictions and mask mandates across the U.S.
# • NYC restaurants are set to open for indoor d…
# "I don’t know if even the guards from 20 or 30 years ago could play in this time right here. It’s creative. It’s co… https://t.co/6qGi8g9KNe
# The discovery of a mysterious metal slab in Turkey was a throwback to November, when a shiny monolith appeared in t… https://t.co/nJRrRJjFNZ
# Dogecoin, a digital currency created as a joke, is now the world’s 10th largest cryptocurrency. Its price is up by… https://t.co/eKc609Dqpd
# Three climbers who set out to scale the summit of K2, the world’s second-tallest mountain, have been missing since… https://t.co/liVhNrIzt1
# Rescue efforts were underway on Monday in Uttarakhand, where a Himalayan glacier broke and caused massive flooding.… https://t.co/eWFl2c9SB1
# ...
